# %%
import pandas as pd
import numpy as np

# %%
nypd_filepath = '/Users/eliaspedersen/Documents/PythonProjects/NYPD_Complaint_Data_Historic.csv'
nypd = pd.read_csv(nypd_filepath)
# Out:
# /Users/eliaspedersen/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print (nypd.iloc[100])
# Out:
# CMPLNT_NUM                               441284640
# CMPLNT_FR_DT                            12/31/2015
# CMPLNT_FR_TM                              20:25:00
# CMPLNT_TO_DT                            12/31/2015
# CMPLNT_TO_TM                              21:25:00
# RPT_DT                                  12/31/2015
# KY_CD                                          344
# OFNS_DESC             ASSAULT 3 & RELATED OFFENSES
# PD_CD                                          114
# PD_DESC                        OBSTR BREATH/CIRCUL
# CRM_ATPT_CPTD_CD                         COMPLETED
# LAW_CAT_CD                             MISDEMEANOR
# JURIS_DESC                        N.Y. POLICE DEPT
# BORO_NM                                  MANHATTAN
# ADDR_PCT_CD                                     28
# LOC_OF_OCCUR_DESC                           INSIDE
# PREM_TYP_DESC               RESIDENCE - APT. HOUSE
# PARKS_NM                                       NaN
# HADEVELOPT                                     NaN
# X_COORD_CD                                  997020
# Y_COORD_CD                                  230319
# Latitude                                   40.7988
# Longitude                                 -73.9539
# Lat_Lon              (40.798847456, -73.953878662)
# Name: 100, dtype: object

# %%
crimeBorough = nypd.loc[:,"BORO_NM"]
print(crimeBorough.iloc[1:100])
# Out:
# 1            QUEENS
# 2         MANHATTAN
# 3            QUEENS
# 4         MANHATTAN
# 5          BROOKLYN
# 6         MANHATTAN
# 7             BRONX
# 8             BRONX
# 9         MANHATTAN
# 10            BRONX
# 11        MANHATTAN
# 12        MANHATTAN
# 13        MANHATTAN
# 14         BROOKLYN
# 15           QUEENS
# 16        MANHATTAN
# 17            BRONX
# 18         BROOKLYN
# 19           QUEENS
# 20         BROOKLYN
# 21           QUEENS
# 22           QUEENS
# 23         BROOKLYN
# 24         BROOKLYN
# 25         BROOKLYN
# 26         BROOKLYN
# 27         BROOKLYN
# 28         BROOKLYN
# 29    STATEN ISLAND
# 30            BRONX
#           ...
# 70         BROOKLYN
# 71           QUEENS
# 72           QUEENS
# 73           QUEENS
# 74            BRONX
# 75            BRONX
# 76         BROOKLYN
# 77         BROOKLYN
# 78           QUEENS
# 79         BROOKLYN
# 80           QUEENS
# 81            BRONX
# 82           QUEENS
# 83           QUEENS
# 84           QUEENS
# 85           QUEENS
# 86         BROOKLYN
# 87         BROOKLYN
# 88         BROOKLYN
# 89        MANHATTAN
# 90         BROOKLYN
# 91            BRONX
# 92            BRONX
# 93            BRONX
# 94           QUEENS
# 95    STATEN ISLAND
# 96    STATEN ISLAND
# 97    STATEN ISLAND
# 98           QUEENS
# 99        MANHATTAN
# Name: BORO_NM, Length: 99, dtype: object

# %%
crimeOccurences = crimeBorough.value_counts()
print(crimeOccurences)
# Out:
# BROOKLYN         1666903
# MANHATTAN        1331760
# BRONX            1209647
# QUEENS           1105621
# STATEN ISLAND     265641
# Name: BORO_NM, dtype: int64

# %%
nCrimes = np.sum(crimeOccurences)
perCrimes = crimeOccurences/nCrimes
print(perCrimes)
# Out:
# BROOKLYN         0.298751
# MANHATTAN        0.238685
# BRONX            0.216799
# QUEENS           0.198155
# STATEN ISLAND    0.047610
# Name: BORO_NM, dtype: float64

# %%
nypd.PD_DESC.unique()
# Out:
# array(['FORGERY,ETC.,UNCLASSIFIED-FELO', nan,
#        'CONTROLLED SUBSTANCE,INTENT TO', 'ASSAULT 3',
#        'ASSAULT 2,1,UNCLASSIFIED', 'CONTROLLED SUBSTANCE, POSSESSI',
#        'WEAPONS POSSESSION 1 & 2', 'LARCENY,PETIT FROM BUILDING,UN',
#        'LARCENY,PETIT OF BICYCLE',
#        'LARCENY,GRAND FROM PERSON, BAG OPEN/DIP',
#        'LARCENY,GRAND FROM PERSON,PICK',
#        'ROBBERY,PERSONAL ELECTRONIC DEVICE',
#        'LARCENY,GRAND FROM EATERY, UNATTENDED', 'CONTEMPT,CRIMINAL',
#        'CRIMINAL MISCHIEF,UNCLASSIFIED 4', 'RAPE 2', 'STRANGULATION 1ST',
#        'WEAPONS POSSESSION 3', 'MARIJUANA, POSSESSION 4 & 5',
#        'INTOXICATED DRIVING,ALCOHOL', 'HARASSMENT,SUBD 3,4,5',
#        'ASSAULT 2,1,PEACE OFFICER', 'ROBBERY,COMMERCIAL UNCLASSIFIED',
#        'CHILD, ENDANGERING WELFARE', 'MISCHIEF, CRIMINAL 4, OF MOTOR',
#        'BURGLARY,COMMERCIAL,NIGHT', 'TRESPASS 2, CRIMINAL',
#        'HARASSMENT,SUBD 1,CIVILIAN', 'CRIMINAL CONTEMPT 1',
#        'LEAVING SCENE-ACCIDENT-PERSONA', 'MARIJUANA, POSSESSION',
#        'CONTROLLED SUBSTANCE, SALE 5', 'LEWDNESS,PUBLIC',
#        'LARCENY,GRAND FROM RESIDENCE, UNATTENDED',
#        'AGGRAVATED HARASSMENT 2', 'VIOLATION OF ORDER OF PROTECTI',
#        'LARCENY,PETIT FROM STORE-SHOPL', 'IMPERSONATION 2, PUBLIC SERVAN',
#        'OBSTR BREATH/CIRCUL', 'LARCENY,PETIT FROM OPEN AREAS,',
#        'PUBLIC ADMINISTATION,UNCLASS M', 'LARCENY,GRAND OF AUTO',
#        'LARCENY,PETIT OF VEHICLE ACCES',
#        'LARCENY,GRAND FROM PERSON,PERSONAL ELECTRONIC DEVICE(SNATCH)',
#        'SEXUAL ABUSE', 'ROBBERY,RESIDENTIAL COMMON AREA',
#        'ROBBERY,BODEGA/CONVENIENCE STORE', 'WEAPONS, POSSESSION, ETC',
#        'MISCHIEF, CRIMINAL 3 & 2, OF M', 'FORGERY,ETC.-MISD.',
#        'ROBBERY,CAR JACKING', 'LARCENY,GRAND FROM PERSON,PURS',
#        'MENACING,UNCLASSIFIED', 'ROBBERY,POCKETBOOK/CARRIED BAG',
#        'BURGLARY,RESIDENCE,NIGHT',
#        'LARCENY,GRAND FROM BUILDING (NON-RESIDENCE) UNATTENDED',
#        'LARCENY,GRAND FROM OPEN AREAS, UNATTENDED',
#        'LARCENY,GRAND BY EXTORTION', 'CONTROLLED SUBSTANCE,POSSESS.',
#        'ROBBERY,OPEN AREA UNCLASSIFIED',
#        'LARCENY,GRAND FROM RETAIL STORE, UNATTENDED',
#        'RECKLESS ENDANGERMENT 2', 'LARCENY,PETIT FROM AUTO',
#        'RECKLESS ENDANGERMENT 1', 'LARCENY,GRAND OF MOTORCYCLE',
#        'MARIJUANA, SALE 4 & 5', 'BURGLARY,RESIDENCE,DAY', 'RAPE 1',
#        'LARCENY,PETIT BY FALSE PROMISE',
#        'LARCENY,GRAND FROM VEHICLE/MOTORCYCLE',
#        'FALSE REPORT UNCLASSIFIED', 'ACCOSTING,FRAUDULENT',
#        'LARCENY,GRAND BY THEFT OF CREDIT CARD',
#        'THEFT OF SERVICES, UNCLASSIFIE',
#        'LARCENY,GRAND BY BANK ACCT COMPROMISE-REPRODUCED CHECK',
#        'LARCENY,GRAND OF BICYCLE', 'BURGLARY,COMMERCIAL,DAY',
#        'LARCENY,GRAND FROM STORE-SHOPL', 'ROBBERY, CHAIN STORE',
#        'CRIMINAL MISCHIEF 4TH, GRAFFIT', 'LARCENY,GRAND BY ACQUIRING LOS',
#        'SEXUAL ABUSE 3,2', 'GAMBLING 2,PROMOTING,UNCLASSIF',
#        'LARCENY,GRAND BY CREDIT CARD ACCT COMPROMISE-EXISTING ACCT',
#        'MISCHIEF,CRIMINAL,    UNCL 2ND', 'BURGLARY,TRUCK DAY',
#        'LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD', 'ROBBERY,DWELLING',
#        'ROBBERY,NECKCHAIN/JEWELRY', 'ARSON, MOTOR VEHICLE 1 2 3 & 4',
#        'RECKLESS ENDANGERMENT OF PROPE', 'TRESPASS 1,CRIMINAL',
#        'LARCENY,GRAND FROM NIGHT CLUB, UNATTENDED',
#        'ROBBERY,PUBLIC PLACE INSIDE', 'ROBBERY,HOME INVASION',
#        'BURGLARY,UNCLASSIFIED,NIGHT', 'FORGERY,DRIVERS LICENSE',
#        'STOLEN PROPERTY 2,1,POSSESSION',
#        'LARCENY,GRAND FROM PERSON,LUSH WORKER(SLEEPING/UNCON VICTIM)',
#        'FORGERY,M.V. REGISTRATION', 'UNAUTHORIZED USE VEHICLE 3',
#        'ARSON 2,3,4', 'DRUG PARAPHERNALIA,   POSSESSE',
#        'LARCENY,GRAND OF VEHICULAR/MOTORCYCLE ACCESSORIES',
#        'ROBBERY,ATM LOCATION', 'PUBLIC ADMINISTRATION,UNCLASSI',
#        'BURGLARY,TRUCK NIGHT', 'LARCENY,PETIT OF LICENSE PLATE',
#        'BURGLARY,RESIDENCE,UNKNOWN TIM',
#        'LARCENY,GRAND BY FALSE PROMISE-NOT IN PERSON CONTACT',
#        'FRAUD,UNCLASSIFIED-MISDEMEANOR', 'MISCHIEF, CRIMINAL 4, BY FIRE',
#        'BURGLARY,UNKNOWN TIME', 'LARCENY,GRAND BY DISHONEST EMP',
#        'FRAUD,UNCLASSIFIED-FELONY', 'BURGLARY,UNCLASSIFIED,UNKNOWN',
#        'LARCENY,GRAND BY BANK ACCT COMPROMISE-ATM TRANSACTION',
#        'LARCENY,PETIT BY CHECK USE', 'UNAUTHORIZED USE VEHICLE 2',
#        'LARCENY,GRAND BY OPEN CREDIT CARD (NEW ACCT)',
#        'PETIT LARCENY-CHECK FROM MAILB',
#        'LARCENY,GRAND BY IDENTITY THEFT-UNCLASSIFIED', 'RAPE 3',
#        'LARCENY,GRAND BY BANK ACCT COMPROMISE-TELLER',
#        'TRAFFIC,UNCLASSIFIED MISDEMEAN', 'DISORDERLY CONDUCT',
#        'BRIBERY,PUBLIC ADMINISTRATION', 'TRESPASS 3, CRIMINAL', 'TAX LAW',
#        'SODOMY 1', 'ADM.CODE,UNCLASSIFIED MISDEMEA', 'COERCION 2',
#        'LARCENY,PETIT BY DISHONEST EMP', 'ROBBERY,BANK',
#        'LARCENY,GRAND FROM PERSON,UNCL',
#        'ROBBERY,LICENSED FOR HIRE VEHICLE', 'IMPRISONMENT 2,UNLAWFUL',
#        'PETIT LARCENY OF ANIMAL', 'CHILD ABANDONMENT',
#        'FALSE REPORT BOMB', 'RESISTING ARREST',
#        'STOLEN PROPERTY 3,POSSESSION', 'NY STATE LAWS,UNCLASSIFIED MIS',
#        'LARCENY,GRAND BY BANK ACCT COMPROMISE-UNCLASSIFIED',
#        'ROBBERY,CLOTHING', 'MAKING TERRORISTIC THREAT',
#        'TRESPASS 4,CRIMINAL SUB 2', 'BAIL JUMPING 3',
#        'CONTROLLED SUBSTANCE,POSSESS.-', 'LARCENY,GRAND PERSON,NECK CHAI',
#        'TAMPERING 3,2, CRIMINAL', 'NY STATE LAWS,UNCLASSIFIED FEL',
#        'AGGRAVATED CRIMINAL CONTEMPT', 'CONTROLLED SUBSTANCE,SALE 3',
#        'LARCENY,GRAND BY BANK ACCT COMPROMISE-UNAUTHORIZED PURCHASE',
#        'MISCHIEF, CRIMINAL 3&2, BY FIR', 'LARCENY, GRAND OF AUTO - ATTEM',
#        'CRIMINAL MIS 2 & 3',
#        'LARCENY,GRAND BY OPEN/COMPROMISE CELL PHONE ACCT',
#        'AGGRAVATED HARASSMENT 1', 'LARCENY,PETIT BY CREDIT CARD U',
#        'OBSCENE MATERIAL - UNDER 17 YE', 'SEXUAL MISCONDUCT,INTERCOURSE',
#        'CONTROLLED SUBSTANCE,SALE 1', 'CONTROLLED SUBSTANCE, INTENT T',
#        'ROBBERY,BAR/RESTAURANT', 'ROBBERY,UNLICENSED FOR HIRE VEHICLE',
#        'LARCENY,GRAND BY FALSE PROMISE-IN PERSON CONTACT',
#        'BURGLARS TOOLS,UNCLASSIFIED', 'RAPE 1,ATTEMPT',
#        'LARCENY,PETIT BY ACQUIRING LOS', 'UNAUTH. SALE OF TRANS. SERVICE',
#        'STOLEN PROPERTY-MOTOR VEH 2ND,', 'IMPERSONATION 1, POLICE OFFICE',
#        'THEFT,RELATED OFFENSES,UNCLASS', 'ROBBERY,LICENSED MEDALLION CAB',
#        'LARCENY, PETIT OF MOPED', 'COERCION 1',
#        'BURGLARY,COMMERCIAL,UNKNOWN TI', 'BURGLARY,UNCLASSIFIED,DAY',
#        'CONTROLLED SUBSTANCE,SALE 2', 'RIOT 2/INCITING',
#        'ROBBERY,CHECK CASHING BUSINESS', 'PROMOTING A SEXUAL PERFORMANCE',
#        'LARCENY,PETIT FROM TRUCK', 'COMPUTER TAMPER/TRESSPASS',
#        'FALSE REPORT 1,FIRE', 'CUSTODIAL INTERFERENCE 2',
#        'ALCOHOLIC BEVERAGE CONTROL LAW', 'ROBBERY,GAS STATION',
#        'MARIJUANA, POSSESSION 1, 2 & 3', 'CONTROLLED SUBSTANCE, SALE 4',
#        'BUILDING MATERIAL', 'CHECK,BAD', 'ROBBERY,ON BUS/ OR BUS DRIVER',
#        'IMPAIRED DRIVING,DRUG', 'FORGERY,PRESCRIPTION',
#        'VEHICULAR ASSAULT (INTOX DRIVE', 'GRAFFITI (ADMINISTRATIVE CODE-',
#        'MENACING 1ST DEGREE (VICT NOT', 'ALCOHOLIC BEVERAGES,PUBLIC CON',
#        'ROBBERY, PAYROLL', 'FALSE ALARM FIRE', 'BRIBERY, POLICE OFFICER',
#        'EXPOSURE OF A PERSON', 'AGRICULTURE & MARKETS LAW,UNCL',
#        'ADM.CODE,UNCLASSIFIED VIOLATIO', 'TORTURE/INJURE ANIMAL CRUELTY',
#        'POSSESSION HYPODERMIC INSTRUME',
#        'INCOMPETENT PERSON,KNOWINGLY ENDANGERING', 'ROBBERY,PHARMACY',
#        'LARCENY,GRAND FROM PIER, UNATTENDED', 'IMPRISONMENT 1,UNLAWFUL',
#        'IMITATION PISTOL/AIR RIFLE', 'LARCENY,PETIT FROM PIER',
#        'INCOMPETENT PERSON,RECKLESSY ENDANGERING', 'ABANDON ANIMAL',
#        'SODOMY 3', 'LARCENY,PETIT FROM COIN MACHIN', 'PERJURY 3,ETC.',
#        'LARCENY,GRAND BY OPEN BANK ACCT', 'KIDNAPPING 2',
#        'FORGERY-ILLEGAL POSSESSION,VEH', 'ROBBERY,BEGIN AS SHOPLIFTING',
#        'RECKLESS DRIVING', 'ROBBERY,LIQUOR STORE',
#        'MARIJUANA, SALE 1, 2 & 3', 'ESCAPE 2,1', 'DIS. CON.,AGGRAVATED',
#        'TAMPERING 1,CRIMINAL', 'PERJURY 2,1,ETC', 'BAIL JUMPING 1 & 2',
#        'LARCENY,PETIT FROM PARKING MET', 'PROSTITUTION 3,PROMOTING BUSIN',
#        'ROBBERY,BICYCLE', 'MENACING 1ST DEGREE (VICT PEAC',
#        'SEX TRAFFICKING', 'LARCENY,GRAND OF TRUCK',
#        'COURSE OF SEXUAL CONDUCT AGAIN', 'SALE SCHOOL GROUNDS 4',
#        'SUPP. ACT TERR 2ND', 'JOSTLING', 'KIDNAPPING 1',
#        'MANUFACTURE UNAUTHORIZED RECOR', 'SEXUAL MISCONDUCT,DEVIATE',
#        'FACILITATION 4, CRIMINAL', 'LARCENY,PETIT OF AUTO',
#        'AGGRAVATED SEXUAL ASBUSE', 'CUSTODIAL INTERFERENCE 1',
#        'PEDDLING,UNLAWFUL', 'INAPPROPIATE SHELTER DOG LEFT',
#        'ASSEMBLY,UNLAWFUL', 'THEFT OF SERVICES- CABLE TV SE',
#        'CAUSE SPI/KILL ANIMAL', 'TAMPERING WITH A WITNESS',
#        'BRIBERY,COMMERCIAL', 'ATTEND/SPECTATOR ANIMAL FIGHTING',
#        'LARCENY,GRAND FROM BOAT, UNATTENDED',
#        'LARCENY,PETIT OF MOTORCYCLE', 'NEGLECT/POISON ANIMAL',
#        'PUBLIC HEALTH LAW,UNCLASSIFIED', 'SALES OF PRESCRIPTION',
#        'ROBBERY,OF TRUCK DRIVER', 'GAMBLING, DEVICE, POSSESSION',
#        'SALE OF UNAUTHORIZED RECORDING', 'LARCENY, GRAND OF MOPED',
#        'SODOMY 2', 'HOMICIDE,NEGLIGENT,VEHICLE',
#        'LARCENY,GRAND FROM TRUCK, UNATTENDED',
#        'MISCHIEF 1,CRIMINAL,EXPLOSIVE', 'SOLICITATION 5,CRIMINAL',
#        'PUBLIC SAFETY,UNCLASSIFIED MIS', 'CRIMINAL DISPOSAL FIREARM 1 &',
#        'PROSTITUTION 3, PROMOTING UNDE', 'NY STATE LAWS,UNCLASSIFIED VIO',
#        'PROSTITUTION', 'ESCAPE 3', 'RECORDS,FALSIFY-TAMPER',
#        'MATERIAL              OFFENSIV', 'CHILD,ALCOHOL SALE TO',
#        'PROSTITUTION, PATRONIZING 4, 3', 'COMPUTER UNAUTH. USE/TAMPER',
#        'FIREWORKS, POSSESS/USE', 'CONSPIRACY 2, 1',
#        'CONFINING ANIMAL IN VEHICLE/SHELTER', 'MENACING,PEACE OFFICER',
#        'LURING A CHILD', 'HOMICIDE, NEGLIGENT, VEHICLE,',
#        'WOUNDS,REPORTING OF', 'PUBLIC HEALTH LAW,GLUE,UNLAWFU',
#        'CHILD,OFFENSES AGAINST,UNCLASS', 'UNLAWFUL POSS. WEAPON UPON SCH',
#        'CREDIT CARD,UNLAWFUL USE OF',
#        'END WELFARE VULNERABLE ELDERLY PERSON', 'NOISE,UNECESSARY',
#        'HEALTH CODE,UNCLASSIFIED MISDE', 'N.Y.C. TRANSIT AUTH. R&R',
#        'LARCENY,PETIT FROM BOAT', 'EAVESDROPPING',
#        'PARKR&R,UNCLASSIFIED VIOLATION', 'GAMBLING 1,PROMOTING,POLICY',
#        'NUISANCE,CRIMINAL,UNCLASSIFIED', 'PLACE FALSE BOMB', 'SEX CRIMES',
#        'APPEARANCE TICKET FAIL TO RESP', 'MONEY LAUNDERING 1 & 2',
#        'LOITERING,GAMBLING,OTHER', 'RIOT 1',
#        'FACILITATION 3,2,1, CRIMINAL', 'STOLEN PROP-MOTOR VEHICLE 3RD,',
#        'OBSCENITY 1', 'LARCENY,GRAND OF BOAT', 'ARSON 1',
#        'GAMBLING 2, PROMOTING, POLICY-', 'FIREWORKS, SALE',
#        'PROSTITUTION 4,PROMOTING&SECUR', 'SOLICITATION 3,2,1, CRIMINAL',
#        'OBSCENITY, PERFORMANCE 3', 'ABORTION 1',
#        'LOITERING TO PROMOTE PROSTITUT', 'GAMBLING 1,PROMOTING,BOOKMAKIN',
#        'POSSESSION ANTI-SECURITY ITEM', 'AIRPOLLUTION',
#        'RADIO DEVICES,UNLAWFUL POSSESS', 'PROSTITUTION 2, COMPULSORY',
#        'HEALTHCARE/RENT.REG.', 'LABOR TRAFFICKING',
#        'LOITERING,UNCLASSIFIED', 'CONSPIRACY 4, 3', 'NUISANCE, CRIMINAL',
#        'EDUCATION LAW, TRUANCY', 'GAMBLING 2, PROMOTING, BOOKMAK',
#        'STOLEN PROPERTY 2,POSSESSION B', 'PRIVACY,OFFENSES AGAINST,UNCLA',
#        'GENERAL BUSINESS LAW / UNCLASSIFIED', 'HEALTH CODE,VIOLATION',
#        'LARCENY, PETIT OF AUTO - ATTEM', 'DOG STEALING',
#        'FORTUNE TELLING', 'BREED/TRAIN/HOST ANIMAL FIGHTING',
#        'ROBBERY,DOCTOR/DENTIST OFFICE', 'LARCENY,PETIT OF BOAT', 'INCEST',
#        'UNDER THE INFLUENCE OF DRUGS', 'CONSPIRACY 6, 5',
#        'ENVIRONMENTAL CONTROL BOARD', 'GENERAL BUSINESS LAW,TICKET SP',
#        'PROSTITUTION 2, UNDER 16', 'TERRORISM PROVIDE SUPPORT',
#        'TRAFFIC,UNCLASSIFIED INFRACTIO', 'POSSES OR CARRY A KNIFE',
#        'EDUCATION LAW,UNCLASSIFIED', 'BRIBERY,FRAUD',
#        'LABOR LAW,EMPLOYING CHILDREN', 'ABSCONDING FROM WORK RELEASE 2',
#        'CIGARETTE,NO TAX STAMP,POSSESS', 'LARCENY,PETIT OF TRUCK',
#        'HOMICIDE,NEGLIGENT,UNCLASSIFIE',
#        'DISSEMINATING A FALSE SEX OFFEND', 'WEAPONS,MFR,TRANSPORT,ETC.',
#        'AIR POLLUTION-MOTOR VEH (ADM C', 'SALE SCHOOL GROUNDS', 'BIGAMY',
#        'WEAPONS,PROHIBITED USE', 'PARK R&R,GAMBLING',
#        'POSTING ADVERTISEMENTS', 'PROSTITUTION,PERMITTING',
#        'ROBBERY,HIJACKING', 'USE OF A CHILD IN A SEXUAL PER',
#        'LOITERING 1ST DEGREE FOR DRUG', 'POSS METH MANUFACT MATERIAL',
#        'ENTERPRISE CORRUPTION',
#        'LARCENY,GRAND BY CREDIT CARD COMPROMISE-UNAUTHORIZE PURCHASE',
#        'CHILD,LICENSED PREMISES', 'LARCENY,GRAND BY FALSE PROMISE',
#        'GRAND LARCENY-CHECK FROM MAILB', 'FIREWORKS',
#        'LARCENY,GRAND FROM COIN MACHIN', 'PROSTITUTION, PATRONIZING 2, 1',
#        'PUBLIC HEALTH LAW,GLUE,INHALAT', 'LOITERING FOR PROSTITUTION OR',
#        'OBSCENITY, MATERIAL 3', 'LARCENY,GRAND FROM PARKING MET',
#        'GYPSY CAB', 'SODOMY,CONSENSUAL', 'A.B.C.,FALSE PROOF OF AGE',
#        'EDUCATION LAW', 'SOLICITATION 4, CRIMINAL',
#        'MARRIAGE,OFFENSES AGAINST,UNCL', 'DRUG, INJECTION OF',
#        'USURY,CRIMINAL', 'NAVIGATION LAW', 'LOITERING,SCHOOL',
#        'USE CHILD TO COMMIT CONT SUB OFF', 'LOITERING,DEVIATE SEX',
#        'WEAPONS,PROHIBITED USE IMITATI', 'PROSTITUTION 1, UNDER 11',
#        'PROMOTING SUICIDE ATTEMPT', 'ABORTION 2, 1, SELF',
#        'FAC. SEXUAL OFFENSE W/CONTROLL', 'ANARCHY,CRIMINAL',
#        'ABORTIONAL ARTICLES,ISSUING', 'EDUCATION LAW,STREET TRADE',
#        'SMOKING TRANSPORTATION FACILIT', 'ROBBERY,DELIVERY PERSON',
#        'UNLAWFUL SALE SYNTHETIC MARIJUANA',
#        'POSSESS PARAPHERNALIA/ANIMAL FIGHTING', 'HIND PROSEC. TERR 2',
#        'FIREARMS LICENSING LAWS', 'FIREWORKS PREV CONV 5 YEARS'],
#       dtype=object)
